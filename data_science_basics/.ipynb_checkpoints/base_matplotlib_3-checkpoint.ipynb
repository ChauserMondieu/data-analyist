# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
import numpy as np
import pandas as pd

# %%
x = np.linspace(1,100,10000)
y = np.sin(x)

plt.figure(figsize=(20,8),dpi=80)

plt.plot(x,y,c='coral',lw=2,ls=':',marker='o',markersize=0.5)

# %%
X = np.arange(0,1000,20).reshape([5,10])
for i in range(len(X[0,:])):
    X[1,i] *= 50

plt.figure(figsize=(12,8),dpi=80)
sc = plt.scatter(np.array(X[0,:]),np.array(X[2,:]),
            s=np.array(X[1,:]),label=X[1,:],
            c=X[1,:],cmap=plt.get_cmap("jet"),
            alpha=0.9)
plt.legend()
plt.colorbar(sc)
plt.title("this is a title")
# Out:
# Text(0.5, 1.0, 'this is a title')
